# %% [markdown]
# # 1. **Prepare datasets**

# %% [markdown]
# * *1*. cek data set train.tsv
#
# sumber file data berdasarkan file challange ppt platinum
#
# a. https://drive.google.com/file/d/1RCHGfn9JJyyReAh8PIIoF8Ch0H3miP0u/view
#
# file ini diganti format txt menjadi tsv
#
# 2. cek data set abusive twiter abusive
#
# sumber file data untuk yang diklasifikasi berdasarkan file challange ppt platinum
#
# b. https://drive.google.com/drive/folders/1qm50pKAnzGGw9gtk--lmwR758aZOVish
#
#
#
# ---
#
# Kesemua file di upload ulang ke github = https://github.com/adamazanos/Challenge-PLATINUM-K6
# dan menggunakan url rawnya, karena merepotkan jika harus sering mengkonek ulang sumber datanya

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# Cek data train

# %%
import pandas as pd

data_train = 'https://raw.githubusercontent.com/adamazanos/Challenge-PLATINUM-K6/master/training_model/train_preprocess.tsv'

df_train = pd.read_table(data_train, header=None, names=["Text","Label"] , encoding='latin-1')
# Out:
#   File "<ipython-input-4-ca5f4db4f02d>", line 6
#     c
#     ^
# IndentationError: unexpected indent

# %%
df_train.head()
# Out:
#                                                 Text     Label
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1  mohon ulama lurus dan k212 mmbri hujjah partai...   neutral
# 2  lokasi strategis di jalan sumatera bandung . t...  positive
# 3  betapa bahagia nya diri ini saat unboxing pake...  positive
# 4  duh . jadi mahasiswa jangan sombong dong . kas...  negative

# %%
df_train.shape
# Out:
# (11000, 2)

# %%
df_train.Label.value_counts()
# Out:
# positive    6416
# negative    3436
# neutral     1148
# Name: Label, dtype: int64

# %% [markdown]
# Kita cek isi dataset challangenya nya dan di dalamnya terdapat
# 1100 data. Terdiri dari:
# *   positive    6416
# *   negative    3436
# *   neutral     1148

# %% [markdown]
# #2. Data Prepocessing

# %% [markdown]
# ## **Text Normalization/Cleansing**

# %% [markdown]
# Demi kemudahan, variable nya kita pakai sesuai template

# %%
import pandas as pd
import re

df_slang = pd.read_csv(r"https://raw.githubusercontent.com/adamazanos/Challenge-PLATINUM-K6/master/twitter_abuse/new_kamusalay.csv", encoding='latin=1', header=None)
df_slang = df_slang.rename(columns={0: 'slang', 1: 'formal'})

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
list_stopwords = set(stopwords.words('indonesian'))

def data_cleaning (tweet):
    #Replace enter
    c1 = re.sub ('\\n','', tweet)
    #Replace RT tag in tweet
    c2 = re.sub ('RT',' ', c1)
    #Replace mention username in tweet
    c3 = re.sub ('USER', ' ', c2)
    #Replace URL (http:// or https://) in tweet
    c4 = re.sub ('(http|https):\/\/s+', ' ', c3)
    #Replace punctuation
    c5 = re.sub ('[^0-9a-zA-Z]+', ' ', c4)
    #Replace emoticon
    c6 = re.sub ('x[a-z0-9]{2}', ' ', c5)
    #Replace Number
    c7 = re.sub ("\d+", ' ', c6)
    #Replace extra space
    c8 = re.sub ('  +', '', c7)
    return c8

def case_folding (tweet):
    return tweet.lower()

def slang_normalization(tweets):
    res = ''
    for item in tweets.split():
        if item in df_slang['slang'].values:
            res += df_slang[df_slang['slang'] == item]['formal'].iloc[0]
        else:
            res += item
        res += ' '
    return res

def stopword_removal(tweet):
    resp = ''
    for item in tweet.split():
        if item not in list_stopwords:
            resp += item
        resp +=' '
    clean = re.sub('  +', ' ', resp)
    return clean

def data_prepocessing(tweet):
    tweet = data_cleaning(tweet)
    tweet = case_folding(tweet)
    tweet = slang_normalization(tweet)
    tweet = stopword_removal(tweet)
    return tweet
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Kita test cleanernya kita beri nama cleansing

# %%
df_train['text_clean'] = df_train.Text.apply(data_prepocessing)

# %%
df_train.head()
# Out:
#                                                 Text     Label  \
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1  mohon ulama lurus dan k212 mmbri hujjah partai...   neutral
# 2  lokasi strategis di jalan sumatera bandung . t...  positive
# 3  betapa bahagia nya diri ini saat unboxing pake...  positive
# 4  duh . jadi mahasiswa jangan sombong dong . kas...  negative
#
#                                           text_clean
# 0  warung dimiliki pengusaha pabrik puluhan terke...
# 1  mohon ulama lurus kmmbri hujjah partai diwlh s...
# 2  lokasi strategis jalan sumatra bandung nya nya...
# 3  betapa bahagia nya unbo paket barang nya bagus...
# 4  aduh mahasiswa sombong kasih kartu kuning bela...

# %%
df_train.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Sortir data berdasarkan sentimen

# %%
neg = df_train.loc[df_train['Label'] == 'negative'].text_clean.tolist()
neu = df_train.loc[df_train['Label'] == 'neutral'].text_clean.tolist()
pos = df_train.loc[df_train['Label'] == 'positive'].text_clean.tolist()

neg_label = df_train.loc[df_train['Label'] == 'negative'].Label.tolist()
neu_label = df_train.loc[df_train['Label'] == 'neutral'].Label.tolist()
pos_label = df_train.loc[df_train['Label'] == 'positive'].Label.tolist()

# %% [markdown]
# kita test total datanya

# %%
total_data = pos + neu + neg
labels = pos_label + neu_label + neg_label

print("Pos: %s, Neu: %s, Neg: %s" % (len(pos), len(neu), len(neg)))
print("Total data: %s" % len(total_data))
# Out:
# Pos: 6416, Neu: 1148, Neg: 3436
# Total data: 11000

# %%
pos['text_clean'] = pos.Text.apply(data_prepocessing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0d80e9710258> in <module>
# ----> 1 pos['text_clean'] = pos.Text.apply(data_prepocessing)
#
# NameError: name 'pos' is not defined

# %%
labels
# Out:
# ['positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  ...]

# %%
neg
# Out:
# ['aduh mahasiswa sombong kasih kartu kuning belajar usahlah politik selesai kuliah nya politik telat dasar mahasiswa ',
#  'pakai kartu kredit baca untung rugi ',
#  'simcard indosat inaktiv gara gara lupa isi pulsa kabar nya aktif pinda pasca bayar ribet banget ',
#  'sifat iri muncul orang orang tujuan hidup ',
#  'pengalaman indosat semoga pelanggan marah marah pelayanan pelanggan indosat ',
#  'anak sulit dinasehati ',
#  ' mengatasi kayak anies sandi becus pasukan kebersihan nya ',
#  'alhamdulillah jalan bugel kesal melulu sempit arah macet makanan sehari ',
#  'respon sayang nya rem nya asli rom distrobitor ',
#  'malu memalukan nih oknum bertanggung ',
#  'makan siang asyik nuansa bali musik nya musik sunda kadang musik khas bali bergantian nya enak adem sayang pesan kopi banget nya berkali kali iya iya hampirjam kopi kopi panas kopi adek kah ciri khas kopi khas nya kopi dingin enak ',
#  ' memuaskan ',
#  'suruh mengaca pemain nya dasar oneng berbicara ala betawi kampungan ',
#  'kafe menyajikan sensasi makan gelap unik sih orang jarang menarik mencoba ',
#  'selamat pagi kecewa berat indihome internet kocek bayar mahal kecewakan pelanggan ',
#  ' terkesan hargaribu mi ayam segelas lemon tea nya disajikan lemon tea jeruk nipis tea ukuran gelas menggigit lidah pelayan dilatih melayani pelanggan sepenuh hati lips service ',
#  ' order jamprivate message ordermain course danminuman makanan yangsudah datangminta makanan sayamenit cancel makanan sungguh kecewa makan pelayanan jelek ',
#  'jujur fahri bego nya banget bingung duduk kursi wakil ketua dewan perwakilan rakyat partai fahri bubarkan komisi pemberantasan korupsi fahri takut komisi pemberantasan korupsi wajar fahri paham teman nya ditangkap ',
#  ' makan kemarin pesan menu beef steak lokasi nyaman menu peningkatan hidangan nya memenuhi pesanan orange squash nya enak soda nya ',
#  ' keliru analisis kesalahan fatal demiz kader demokrat top pembicaraan tahap negoisasi gerindra nya demiz izin meikarta hica pandjaitan hadir peresmian meikarta ',
#  ' pelayana bagus banget jelek banget ',
#  ' mengambil keputusan tertutup peraturan mitra nya perusahaan ',
#  'order darihari nih aduh ',
#  ' nama nya diharapkan malam inti makanan nya nasi hitam pilihan lauk ala warung nasi nya standar sih standar harga mahal malas pelayanan nya super asalan ramah lokasi mudah dijangkau jalan riau at all pikir pikir ',
#  'iya maksud gue haha sih beli bekas pemain madrid kesal gue sudi uhuu ',
#  ' sandiaga omongan nya sok deh ',
#  'sumpah kecewa nasi uduk langganan kerupuk nya ganti kerupuk pelangi kecewa banget parah bohong ',
#  'belajar setya novanto mempermasalahkan meme masker jatuh citra nya ',
#  'makanan nya enak terkenal makan harga nya masuk akal bakmi pelayanan nya ramah sopan lokasi perumahan tua bersih mengecewakan mahal dibanding pesaing nya ',
#  'negara indonesia terancam bangkrut ',
#  'menyesal mengadakan acara makan malam restoran rekan rekan kantor pesan menu nya beef steak buntut bakar udon soup hot chocolate es kopi makanan standar istimewa istimewa nya elite ',
#  ' kecewa liga champions disiarkan channel channel indihome channel lokal channel sports nya perjuangkan hak siar pelanggan bayar mahal kecewa ',
#  'tolong cek pesan langsung cape marah marah indosat melulu ',
#  ' mudah nya teriak pembohong pembangkang salah orang tua becus mendidik anak ',
#  'bakar mati sekeluarga ',
#  'prabowo pasukan orang stres indonesia hancur ',
#  'maklumlah jokowi bawa perasaan klaim meng klaim nya pokok nya presiden ri alay lebay capcay puyung hai ',
#  'pesan es jeruk nipis bakso es nya sirup pasaran bakso nya panas cenderung dingin layak direkomendasikan ',
#  'kayak nya pagi macet banget ya tur bus sejam ',
#  'muka kayak cepot medan ku matikan anak ',
#  ' imam pencitraan publikasi maaf banget muak gue ',
#  ' anies nyalon presiden mending nyalon barbershop ',
#  ' mengerti nih kubu jokowi ideologi pikiran nya sesuai ya membenci syariat kekhalifahan mendukung budaya syirik mendukung pembakaran bendera brkalimt tauhid pilih jokowi takut kena azab ',
#  'kasihan lihat muka nya jokowi sontoloyo ',
#  'rt anak ketahuan mencuri helem bip contoh sampah masyarakat dimusnahkan ',
#  'urgent koneksi data internet buruk ',
#  ' marah indosat ',
#  'dove mahal ',
#  'senin pagi ku mandi hujan plus terjebak macet bikin kesal ',
#  'makanan minuman restoran harga nya mahal enak ',
#  ' pakai paket yellow lo pulsa berkurang dasar tukang tipu ',
#  ' makan sekian menginjak lembang kecewa berat makan keluarga lembang sebelah rm ampera ayam goreng kuning nya berasa asin ayam bakar nya kecap daging nya keras lalat ',
#  ' makanan standar masakan rumahan nyaman sayang nya siang panas ',
#  'skeptis ',
#  'kacamata patah galau ',
#  ' percaya amin rakus zaman zaman nya orang nya menjelekkan orang nya agama ',
#  'langkan sesat agama maju kolong langit ',
#  'beli ski aqua sptharga nyak menyesal malk ',
#  ' bikin penasaran kafe sih makan gelap nya aneh bikin penasaran makan nya standar sih nothing spesial ',
#  'copot keanggotaan polisi perusak nama korp ',
#  'aksesoris bawaan nya charger buku panduan bus indonesia nya membantu ',
#  'dewan perwakilan rakyat bubarkan berguna ',
#  ' tepung segitiga biru warna tepung nya biru biru nya penipuan ',
#  'martabak cocok pancake oke manis pas manis enek mengharapkan tekstur lembab ala martabak manis nama nya tekstur nya bolu martabak enak dinikmati dingin awet disimpan suhu ruang harga nya relatif mahal dibandingkan hehe deh beli ',
#  ' indosat lemah otak banget minimal dipakai unduh kecepatan nya kisarankbps senang ',
#  'pemandangan ditawarkan bagus staf nya ramah sayang menu nya lengkap sesuai harga mahal ',
#  'minimal indomie goreng exp date kurangbulan kadaluarsa aroma mi tengik bumbu menggumpal saus nya berubah warna tekstur ',
#  'keberatan ',
#  'masyarakat bosan muak dengar janji janji calon presiden ',
#  'salah benci film tokoh utama nya mati jalan cerita ',
#  'cape banget sumpah menunggu paket jne ',
#  'agama buddha agama sesat aliran nya ',
#  'main game bosan menonton film menarik buka media sosial isi nya kebencian ',
#  'transjakarta kemarin top kartu transjakarta sayaribu halte permai koja pagi pakai kartu top upsama petugas nya tolong hati uang pelanggan sih bertanggung ',
#  ' jokowi presiden nya muka gila ',
#  'didit prabowo ciptakan lgbt homo laknatullah anak prabowo prabowo nya mengajarkan ',
#  'makanan khas sunda oke kotor nya sayang ramai pengunjung nya antre sih kekurangan nya ',
#  'intel indomie telur perut doang besarkan otak kosong ',
#  'orang bekasi orang perantauan mampus kontrakan kayak kuburan warung nasi laku orang bekasi sekolah tamat ',
#  'lakukan tugas mu es serang keluarga sayang ',
#  'sinyal telkomsel bikin marah marah ',
#  ' suka orang pelit biarkan orang pelit kuburan nya sempit ',
#  ' suka jokowi pilih prabowo ',
#  ' negara indonesia tercinta rakyat nya berani mencibir presiden nya seenak jidat mengotak bacot giliran diusut komen nya bawa jalur hukum deh menangis menangis suka jijik manusia ',
#  ' siang mampir keluarga makan siang cost bin memesan makanan besertasatu gelas es kelapa adalahdua gelas es kelapa protes pelayan bilang memesangelas menerima order bersikeras memberikanbuah kartu es ',
#  ' udang dibalik batu partai mendukung jokowi ',
#  'ser sor panen nasi bungkus desember front pembela islam front pembela islam semkin sor ser tenggelam kubangan ',
#  ' tidur galau memikirkan ',
#  'islam siang malam pagi ribut banget teriak teriak mesjid coba kristen tindas dasar agama munafik otak toleransi nya agama berisik huru hara ',
#  'maaf minimal nomer pakai sel daerah situ mengalahkan ku sinyal nya jelek ',
#  ' kesal marah bakar kartu indosat ',
#  ' pakai baju papua baju nya cantik bernilai budaya orang makan cantik jelek jelek ',
#  ' untung ',
#  'positif atmosfir kursi meja kayu berkualitas negatif menu makanan tersedia harga nilai uang pelayanan memuaskan nasi liwet standar orderkuali asin standar asin banget ',
#  ' cocok produk ponds ',
#  'marah gue indosat ampas banget puasa ',
#  'penjajahan nya penjajah nya penghianat kali tantangan nya penghianat agama muslim kafir memerangi kaum nya ',
#  'konflik ',
#  'lemah otak banget anjir bikin senang pakai indosat ',
#  ' pesan iga bakar sup iga iga bakar pesan tingkat kepedasan leveltapi sepedas dibayangkan iga nya sup nya vetsin nya menu utama iga menemukan serengit point nya ',
#  'bongkar susilo bambang yudhoyono negeri hancur ',
#  ' anis baswedan diganti kerja nya menteri ',
#  'tokoh tokoh giat giat nya menyesatkan umat islam ajaran islam ',
#  'ayo minimal media berjuang bela muslim rohingya saudara mengalami penderitaan pembantaian kelompok agama biadab intolerant ',
#  'indosat bikin marah ',
#  ' enak sumpah mahal ',
#  'saran beli makan rumah makan jasa harga mahal pelayanan sesuai harga makanan nya ',
#  ' ramai masuk daftar tunggu lebihmenit ditelepon kosong pesan makanan pasta sup omelette pasta sup bersamaan omelette jam menghabiskan makanan pasta nya keras makanan nya dingin kaca meja makan kotor ',
#  'musim hujan hujan tenang takut kebanjiran tinggal kota isian perhatian ',
#  'kayak profesor mending dipergi gelar profesor nya ',
#  'tenggelamkan partai sengkuni ',
#  'gue spam indosat bodoamat gue marah ',
#  'mister mahal makanan makanan laku indonesia mister ',
#  ' training bandung acara makan malam diadakan caf lokasi nya strategis jalan dago simpang dago layout suasana cafe nya oke makanan nya enak makanan pesan habiskan pulang cafe kelaparan ',
#  'nasi campur terkenal bandung info nya nasi campur bandung mengandung berasa standar nasi campur babi merah babi panggang sate babi manis bakso goreng jerohan manis layanan ramah maklum generasi tua beraksi lokasi makan lumayan bersih berat ',
#  'nama nya jokowi pencitraan doang ',
#  ' keluarga rusak ya rumah tangga hancur ahok verro penjahat ',
#  'ribet minimal telepon pusat panggilan pulsa terkuras ',
#  'jahat sih bangsat tofalemon ibadah lanjutkan kakak kendor berbaik hati bajingan ',
#  'turunkan anies baswedan sandi uno becus membereskan jakarta ',
#  'barang beda dipesan ',
#  'pelacur dijadikan kandung presiden jokowi menutupi keterlibatan ayah kandung nya anggota partai komunis indonesia ',
#  ' sabar ',
#  ' bosan film indonesia pemeran nya orang ',
#  'hati membenci pemerintah ',
#  'mencuri ',
#  'sih pesek mengompol kali muka pantat beda nya ',
#  ' sih bandung macet banget ',
#  'jujur allah tahunkemarin menyesal pilih jokowi ',
#  ' partai komunis indonesia hadir organisasi masyarakat islam radikal front pembela islam hati bakar organisasi masyarakat islam wahabbi bekingan saudi musnahkan ',
#  'wirid kesetanan dasar manusia bodoh mendalami agama pakai ajaran sesat menyesatkan ',
#  'bukalapak gangguan ya kadang transaksi pemberitahuan pelapak mengcancel ordderan itukan merugikan pelapak ',
#  ' acara buka hidangan enak pesan affogato ice krim nya dipisahkan espresso mencampur sesuai selera salmon steak nya segar kulit salmon nya keras nya kulkas freezer menu utama enak ',
#  'tolak reklamasi tumbangkan patung cina komunis tuban undang undang hak pribumi kedaulatan negara diinjak injek cinta tanah air rela aset tanah negara dijual bangsa pendatang berjuang enak menguasai negara kesatuan republik indonesia ',
#  ' kali tertipu partai cukong partai dibeli ',
#  ' bersyukur ',
#  'makan restoran kafe mahal enak ',
#  ' islam agama bermoral cacat lonte ',
#  'kristen agama sesat menyesatkan umat titik ',
#  ' proyek trans papua digagas jaman susilo bambang yudhoyono presiden trans papua dilanjutkan diselesaikan presiden periode periode orang bodoh bertepi ku ku prestasi presiden tok ',
#  'malam proses pengembalian dana cancellation tiket hampirbulan ditransfer call cor pelayanan pelanggan bantu kecewa ',
#  'menyesal salah beli mahal lageee ',
#  'info tabungan mandiri mitra usaha ya website ',
#  'kacau banget nih gojek saldo gopay terkuras haduuh ',
#  'pioner batagor bandung batagor iksan batagor riri ikan lumayan seenak ',
#  ' komikus dibayar partai ya nya sengaja menjatuhkan presiden pemilihan presiden ',
#  'negara kian bobrok dipimpin presiden gemar menipu berbohong tenggelamkan hancurkan dinanti ',
#  ' warung kopi nih sok sok an pesan matcha papermint eh nya minum pepsodent ',
#  'pertandingan persija berkualitas ',
#  'pala peang kepolisian republik indonesia berjihad dasar cebong bodoh ',
#  'selebihnya kesal sanksi pssi ',
#  ' cemburu sapu nya hak ',
#  'tembak mati lgbt hidup menambah menambah virus ',
#  ' jokowi plin plan bu susi melempem ',
#  ' marah sinyal indosat ',
#  'ojek online tolol muka driver ojek online anjing babi ',
#  'bongkar bang biar melacur ',
#  'staf nya ramah menyajikan makanan banting banting piring menaruh minuman paro nya sembarang informasikan minuman harga makanan mahal makanan sayuran nya asin ',
#  ' bagus makanan nya kualitas kampuslah pelayanan nya cepat parkir nya susah kebersihan nya ',
#  ' ciri jokower iqsekolam otak mentok nya menuduh lawan nya anti pancasilalah htilah aneh menuduh lawan nya pikir volume otak nya cetek ',
#  'bayar mahal kualitas murahan ',
#  ' sih bocah ingusan pendukung front pembela islam ketua nya bajingan ',
#  ' pagi niatan berangkat rumah eh jalan macet serobot pagi mengumpat ',
#  'suka galau mengantuk pas belajar bikin bosan nya ',
#  ' meninggalkan makan makanan order kebanyakan it si ok ramai keluarga sore menunggu jam order tersedia order dipesan dibuatkan jam ya menunggu info stok ',
#  ' resto sapulidi rekomendasi internet baca pemandangan bagus makan sawah tertarik berubah buruk parkir tersedia jalan akses rusak nya akses ',
#  ' lo angkahong pengadaan lahan pasar jambubogor merugikan negaram dalang nya bima arya disentuh komisi pemberantasan korupsi eh salah direktur komisi pemberantasan korupsi dirangkul wali kota pilihan kepala daerah ',
#  'mc donalds sih senang mc donalds terjamin suka mandi cuci kakus nya oke lokasi nya daerah anak muda bangunan mencerminkan anak muda sayang nya parkir nya menyesalkan mencari parker ',
#  'utang negara beda utang perorangan orang nya mati utang nya bingung bayar negara aakan mati rakyat rugi ',
#  'mampus sookoriin wkwk pengguna kesal mahal ',
#  ' kali pergi bandung kuis butcher a to mengunjungi memiliki teh terbaik the delicious steak dinamakan entre cote sayang kunjungan mengecewakan menu tertulis pelayan nya menginfokan menghidangkan steak izin penggila entre cote lanjutan ',
#  'kangen pepes peda sambal dadak nya pedas nya pedas level nya teman ku pencinta pedas diajak makan siang menu spesial nya ayam goreng bakar ayam kampung asli menu tambahan karedok leunca tumis kangkung enak pas bumbu nya ',
#  ' nya strategis parkiran nya luas masuk staf nya ramah nilai plus marugame makanan nya enak disajikan langsung segar enak makan nya harga nya bersahabat porsi nya lumayan ',
#  'ribuan menu tinggal pilih pesan bayar santap berkunjung pekan suasana ramai sulit duduk bayar nyeri harga makanan mahal dibandingkan pengunjung menikmati atmosfer nya ',
#  'bakpao minimal yen puluhan terkenal menyediakan siomay enak ',
#  ' pencinta ayam makan kentaki fried chicken pergi anak terkadang fasilitas letak makan pertimbangan keponakan berumurtahun aktif memilih kentaki fried chicken jalan merdeka luas fasilitas bermain anak tersedia menunggu pesanan anak anak main gratis ',
#  ' bangsat ',
#  'makan menyenangkan suasana hening udara sayup sayup sayang sawah nya gundul cuaca mendukung makanan enak dicoba buncis oncom nya enak ',
#  'mie nya mantap enak banget kuah nya tambahan nya pedas pedas tinggal cengek ',
#  ' nya nyaman makanan nya enak harga nya mahal enak berkumpul teman keluarga menu nya unik memesan bumbu memilih jenis pasta nya menu favorit creamy bloody mary baked ',
#  ' nya kampus pulang kantor transit angkutan kota kalapa bubat nya nyaman diperhatikan restoran pas masuk nya indah banget suasana nya kayak suasana teras bangunan penataan lighting nya bagus berpasangan kesan nya romantis nyaman banget pelayan nya ramah terbaik ',
#  'soto kuah bening segar tambahan lauk pauk enak dimakan bersamaan soto nya ',
#  ' januari rombongan jakarta nya makan daerah lembang jalanan macet decide coba tjendana bistro buka suasana nya bagus interior nya suka ditambah garmen kolam rombongan dikasih pribadi room garmen serasa dilembang beruntung menu nya menarik ',
#  ' menyenangkan berkumpul teman teman pasangan makanan minuman disediakan variatif harga terjangkau ',
#  ...]

# %% [markdown]
# #3. **Feature Extraction**

# %%
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from collections import defaultdict

max_features = 100000
tokenizer = Tokenizer(num_words=max_features, split=' ', lower=True)
tokenizer.fit_on_texts(total_data)
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("tokenizer.pickle has created!")

X = tokenizer.texts_to_sequences(total_data)

vocab_size = len(tokenizer.word_index)
maxlen = max(len(x) for x in X)

X = pad_sequences(X)
with open('x_pad_sequences.pickle', 'wb') as handle:
    pickle.dump(X, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("x_pad_sequences.pickle has created!")
# Out:
# tokenizer.pickle has created!
# x_pad_sequences.pickle has created!

# %%
Y = pd.get_dummies(labels)
Y = Y.values

with open('y_labels.pickle', 'wb') as handle:
    pickle.dump(Y, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print("y_labels.pickle has created!")
# Out:
# y_labels.pickle has created!

# %% [markdown]
# #  4.**Prepare train & test datasets/Splitting Dataset**

# %% [markdown]
# Split dataset menjadi 80% untuk train dan 20% untuk test.

# %%
from sklearn.model_selection import train_test_split

file = open("x_pad_sequences.pickle",'rb')
X = pickle.load(file)
file.close()

file = open("y_labels.pickle",'rb')
Y = pickle.load(file)
file.close()

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %% [markdown]
# # 5. **Penerapan Konsep Neural Network**

# %%
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Flatten
from tensorflow.keras import backend as K

# %%
embed_dim = 100

model_nn = Sequential()
model_nn.add(Embedding(max_features, embed_dim, input_length=maxlen))
model_nn.add(Flatten())
model_nn.add(Dense(3, activation='sigmoid'))

model_nn.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model_nn.summary())

es = EarlyStopping(monitor='val_loss', mode='min',patience=3 , verbose=1)
history = model_nn.fit(X_train, y_train, epochs=10, batch_size=10, validation_data=(X_test, y_test), verbose=1, callbacks=[es])
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_13 (Embedding)    (None, 58, 100)           10000000
#
#  flatten_6 (Flatten)         (None, 5800)              0
#
#  dense_13 (Dense)            (None, 3)                 17403
#
# =================================================================
# Total params: 10,017,403
# Trainable params: 10,017,403
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 880/880 [==============================] - 91s 103ms/step - loss: 0.3408 - accuracy: 0.7653 - val_loss: 0.2603 - val_accuracy: 0.8355
# Epoch 2/10
# 880/880 [==============================] - 91s 104ms/step - loss: 0.1606 - accuracy: 0.9106 - val_loss: 0.2486 - val_accuracy: 0.8541
# Epoch 3/10
# 880/880 [==============================] - 90s 102ms/step - loss: 0.0781 - accuracy: 0.9605 - val_loss: 0.2648 - val_accuracy: 0.8545
# Epoch 4/10
# 880/880 [==============================] - 91s 103ms/step - loss: 0.0421 - accuracy: 0.9792 - val_loss: 0.3011 - val_accuracy: 0.8423
# Epoch 5/10
# 880/880 [==============================] - 88s 101ms/step - loss: 0.0280 - accuracy: 0.9830 - val_loss: 0.3333 - val_accuracy: 0.8382
# Epoch 5: early stopping

# %%
from sklearn import metrics

predictions = model_nn.predict(X_test)
y_pred = predictions
matrix_test = metrics.classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print("Testing selesai")
print(matrix_test)
# Out:
# 69/69 [==============================] - 0s 2ms/step
# Testing selesai
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.77       685
#            1       0.80      0.65      0.72       233
#            2       0.88      0.90      0.89      1282
#
#     accuracy                           0.84      2200
#    macro avg       0.82      0.78      0.79      2200
# weighted avg       0.84      0.84      0.84      2200

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

kf = KFold(n_splits=5,random_state=42,shuffle=True)

accuracies = []

y = Y

embed_dim = 100

for iteration, data in enumerate(kf.split(X), start=1):

    data_train   = X[data[0]]
    target_train = y[data[0]]

    data_test    = X[data[1]]
    target_test  = y[data[1]]

    model_nn = Sequential()
    model_nn.add(Embedding(max_features, embed_dim, input_length=maxlen))
    model_nn.add(Flatten())
    model_nn.add(Dense(3, activation='sigmoid'))

    model_nn.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])

    es = EarlyStopping(monitor='val_loss', mode='min',patience=3 , verbose=0)
    history = model_nn.fit(X_train, y_train, epochs=10, batch_size=10, validation_data=(X_test, y_test), verbose=0, callbacks=[es])

    predictions = model_nn.predict(X_test)
    y_pred = predictions

    # for the current fold only
    accuracy = accuracy_score(y_test.argmax(axis=1), y_pred.argmax(axis=1))

    print("Training ke-", iteration)
    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
    print("======================================================")

    accuracies.append(accuracy)

# this is the average accuracy over all folds
average_accuracy = np.mean(accuracies)

print()
print()
print()
print("Rata-rata Accuracy: ", average_accuracy)
# Out:
# 69/69 [==============================] - 0s 2ms/step
# Training ke- 1
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77       685
#            1       0.79      0.65      0.71       233
#            2       0.87      0.91      0.89      1282
#
#     accuracy                           0.84      2200
#    macro avg       0.81      0.77      0.79      2200
# weighted avg       0.84      0.84      0.84      2200
#
# ======================================================
# 69/69 [==============================] - 0s 2ms/step
# Training ke- 2
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78       685
#            1       0.79      0.65      0.72       233
#            2       0.88      0.90      0.89      1282
#
#     accuracy                           0.84      2200
#    macro avg       0.82      0.78      0.80      2200
# weighted avg       0.84      0.84      0.84      2200
#
# ======================================================
# 69/69 [==============================] - 0s 2ms/step
# Training ke- 3
#               precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77       685
#            1       0.79      0.65      0.71       233
#            2       0.86      0.93      0.89      1282
#
#     accuracy                           0.84      2200
#    macro avg       0.82      0.77      0.79      2200
# weighted avg       0.84      0.84      0.84      2200
#
# ======================================================
# 69/69 [==============================] - 0s 2ms/step
# Training ke- 4
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.78       685
#            1       0.81      0.67      0.73       233
#            2       0.88      0.91      0.90      1282
#
#     accuracy                           0.84      2200
#    macro avg       0.82      0.78      0.80      2200
# weighted avg       0.84      0.84      0.84      2200
#
# ======================================================
# 69/69 [==============================] - 0s 2ms/step
# Training ke- 5
#               precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76       685
#            1       0.78      0.68      0.72       233
#            2       0.87      0.91      0.89      1282
#
#     accuracy                           0.84      2200
#    macro avg       0.81      0.78      0.79      2200
# weighted avg       0.83      0.84      0.83      2200
#
# ======================================================
#
#
#
# Rata-rata Accuracy:  0.8390000000000001

# %% [markdown]
# Hasilnya nilai rata-rata accuracy pada angka 0.8390000000000001. Ini menunjukkan model kita cukup stabil pada angka 0.83.

# %%
# history.history
import matplotlib.pyplot as plt
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %matplotlib inline
plot_history(history)

# %%
model_nn.save('model_nn.h5')
print("Model has created!")
# Out:
# Model has created!

# %% [markdown]
# # 6.  **Penerapan Konsep LSTM**

# %% [markdown]
# Jalankan training dengan metode LSTM. Arsitektur LSTM ini dibangun menggunakan framework Tensorflow.

# %%
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, SimpleRNN, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Flatten
from tensorflow.keras import backend as K

# %% [markdown]
# Adapun arsitektur LSTM yang dibangun sebagai berikut:
#
#
# *   Input Layer: Data teks setelah dilakukan Feature Extraction, dikondisikan menjadi sebuah matrix berdimensi 100.
# *   Unit Layer: Pada bagian ini diterapkan unit/neuron sejumlah 64. Pada tahap ini pula fitur Dropout diterapkan guna meminimalisir overfitting.
# *   Fully-connected Layer: Setelah proses convolution, dikondisikan sebagai input untuk Multi-layer Perceptron terdiri dari 10 input dan 3 output. Pada tahap ini diimplementasikan pula aktivasi "softmax".
#
# Untuk mencegah overfitting, kita menerapkan EarlyStopping. Sehingga, meskipun epoch belum selesai, training sudah selesai.

# %%
embed_dim = 100
units = 64

model_lstm = Sequential()
model_lstm.add(Embedding(max_features, embed_dim, input_length=X.shape[1]))
model_lstm.add(LSTM(units, dropout=0.2))
model_lstm.add(Dense(3,activation='softmax'))

adam = optimizers.Adam(lr = 0.001)
model_lstm.compile(loss = 'categorical_crossentropy', optimizer = adam, metrics = ['accuracy'])
print(model_lstm.summary())

es = EarlyStopping(monitor='val_loss', mode='min', patience=3 , verbose=1)
history = model_lstm.fit(X_train, y_train, epochs=10, batch_size=10, validation_data=(X_test, y_test), verbose=1, callbacks=[es])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 58, 100)           10000000
#
#  lstm_1 (LSTM)               (None, 64)                42240
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 10,042,435
# Trainable params: 10,042,435
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 880/880 [==============================] - 117s 130ms/step - loss: 0.4890 - accuracy: 0.8045 - val_loss: 0.4299 - val_accuracy: 0.8386
# Epoch 2/10
# 880/880 [==============================] - 112s 127ms/step - loss: 0.2338 - accuracy: 0.9123 - val_loss: 0.4355 - val_accuracy: 0.8395
# Epoch 3/10
# 880/880 [==============================] - 115s 130ms/step - loss: 0.1260 - accuracy: 0.9518 - val_loss: 0.4939 - val_accuracy: 0.8409
# Epoch 4/10
# 880/880 [==============================] - 115s 131ms/step - loss: 0.0766 - accuracy: 0.9691 - val_loss: 0.5948 - val_accuracy: 0.8314
# Epoch 4: early stopping

# %% [markdown]
# ## Confussion Matrix, Accuracy, F1, Recall, Precision

# %% [markdown]
# Langkah selanjutnya adalah "Evaluation". Module "classification_report" dari Sklearn merupakan salah satu modul untuk melakukan "Evaluation". Pada tahap evaluasi ini kita akan menerapkan metode evaluasi Accuracy, Precision, Recall dan F1-Score.

# %%
from sklearn import metrics

predictions = model_lstm.predict(X_test)
y_pred = predictions
matrix_test = metrics.classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print("Testing selesai")
print(matrix_test)
# Out:
# 69/69 [==============================] - 1s 12ms/step
# Testing selesai
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77       685
#            1       0.78      0.70      0.74       233
#            2       0.89      0.88      0.88      1282
#
#     accuracy                           0.83      2200
#    macro avg       0.80      0.79      0.80      2200
# weighted avg       0.83      0.83      0.83      2200

# %% [markdown]
# Hasilnya nilai F1 Score ada pada angka 0.83 untuk Negative, **??** untuk Neutral, dan 0.91 untuk Positive. Hasil ini bisa dikatakan cukup bagus untuk sebuah model, namun kecenderungan untuk memilih sentimen netralnya lemah.

# %% [markdown]
# ## Cross Validation

# %%
# Untuk lebih menyakinkan lagi, kita juga bisa melakukan "Cross Validation"
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

kf = KFold(n_splits=5,random_state=42,shuffle=True)

accuracies = []

y = Y

embed_dim = 100
units = 64

for iteration, data in enumerate(kf.split(X), start=1):

    data_train   = X[data[0]]
    target_train = y[data[0]]

    data_test    = X[data[1]]
    target_test  = y[data[1]]


    model_lstm = Sequential()
    model_lstm.add(Embedding(max_features, embed_dim, input_length=X.shape[1]))
    model_lstm.add(LSTM(units, dropout=0.2))
    model_lstm.add(Dense(3,activation='softmax'))

    adam = optimizers.Adam(lr = 0.001)
    model_lstm.compile(loss = 'categorical_crossentropy', optimizer = adam, metrics = ['accuracy'])

    es = EarlyStopping(monitor='val_loss', mode='min',patience=3 , verbose=0)
    history = model_lstm.fit(X_train, y_train, epochs=10, batch_size=10, validation_data=(X_test, y_test), verbose=0, callbacks=[es])

    predictions = model_lstm.predict(X_test)
    y_pred = predictions

    # for the current fold only
    accuracy = accuracy_score(y_test.argmax(axis=1), y_pred.argmax(axis=1))

    print("Training ke-", iteration)
    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
    print("======================================================")

    accuracies.append(accuracy)

# this is the average accuracy over all folds
average_accuracy = np.mean(accuracies)

print()
print()
print()
print("Rata-rata Accuracy: ", average_accuracy)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 69/69 [==============================] - 1s 12ms/step
# Training ke- 1
#               precision    recall  f1-score   support
#
#            0       0.80      0.70      0.75       685
#            1       0.73      0.77      0.75       233
#            2       0.87      0.91      0.89      1282
#
#     accuracy                           0.83      2200
#    macro avg       0.80      0.80      0.80      2200
# weighted avg       0.83      0.83      0.83      2200
#
# ======================================================
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 69/69 [==============================] - 1s 12ms/step
# Training ke- 2
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       685
#            1       0.75      0.69      0.72       233
#            2       0.88      0.89      0.88      1282
#
#     accuracy                           0.83      2200
#    macro avg       0.80      0.78      0.79      2200
# weighted avg       0.83      0.83      0.83      2200
#
# ======================================================
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 69/69 [==============================] - 1s 12ms/step
# Training ke- 3
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78       685
#            1       0.76      0.77      0.77       233
#            2       0.89      0.90      0.90      1282
#
#     accuracy                           0.85      2200
#    macro avg       0.81      0.81      0.81      2200
# weighted avg       0.84      0.85      0.85      2200
#
# ======================================================
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 69/69 [==============================] - 1s 13ms/step
# Training ke- 4
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       685
#            1       0.73      0.77      0.75       233
#            2       0.87      0.89      0.88      1282
#
#     accuracy                           0.82      2200
#    macro avg       0.79      0.79      0.79      2200
# weighted avg       0.82      0.82      0.82      2200
#
# ======================================================
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 69/69 [==============================] - 1s 12ms/step
# Training ke- 5
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78       685
#            1       0.76      0.71      0.73       233
#            2       0.89      0.89      0.89      1282
#
#     accuracy                           0.84      2200
#    macro avg       0.81      0.80      0.80      2200
# weighted avg       0.84      0.84      0.84      2200
#
# ======================================================
#
#
#
# Rata-rata Accuracy:  0.8335454545454546

# %% [markdown]
# Hasilnya nilai rata-rata accuracy pada angka 0.8335454545454546. Ini menunjukkan model kita cukup stabil pada angka 0.83.

# %% [markdown]
# ## Visualization LSTM

# %%
# history.history
import matplotlib.pyplot as plt
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %matplotlib inline
plot_history(history)

# %% [markdown]
# Hasilnya jika kita melihat visualisasinya model yang kita kembangkan tergolong Underfitting. Disinyalir karena:
#
#
# *   Data training terlalu sedikit
# *   Proses training berhenti terlalu cepat. Mungkin saja penerapan EarlyStopping untuk kasus kita tidak terlalu tepat

# %%
model_lstm.save('model_lstm.h5')
print("Model has created!")
# Out:
# Model has created!

# %% [markdown]
# # 7. **Data Tweet**

# %%
data_twt = 'https://raw.githubusercontent.com/adamazanos/Challenge-PLATINUM-K6/master/twitter_abuse/data.csv'

df_tweet = pd.read_csv(data_twt, encoding='latin-1')

# %%
df_predict = df_tweet[['Tweet']].copy()
df_predict.head()
# Out:
#                                                Tweet
# 0  - disaat semua cowok berusaha melacak perhatia...
# 1  RT USER: USER siapa yang telat ngasih tau elu?...
# 2  41. Kadang aku berfikir, kenapa aku tetap perc...
# 3  USER USER AKU ITU AKU\n\nKU TAU MATAMU SIPIT T...
# 4  USER USER Kaum cebong kapir udah keliatan dong...

# %% [markdown]
# #8.**Predict**

# %%
import re
from keras.models import load_model
import numpy as np
import pickle
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sentiment = ['negative', 'neutral', 'positive']

def get_sent(sent):
    if sent==0:
        sent='negative'
    elif sent==1:
        sent='neutral'
    else: sent='positive'
    return sent

file_tokenizer = open('tokenizer.pickle', 'rb')
file_sequencer = open('x_pad_sequences.pickle', 'rb')
load_tokenizer = pickle.load(file_tokenizer)
load_sequencer = pickle.load(file_sequencer)
file_sequencer.close()
model_nn = load_model('model_nn.h5')
model_lstm = load_model('model_lstm.h5')

# %% [markdown]
# ##A. Predict Neural Network

# %% [markdown]
# Predict Text

# %%
input_text = """
syukur
"""

text = [data_prepocessing(input_text)]
feature = load_tokenizer.texts_to_sequences(text)
sequences= pad_sequences(feature, maxlen=load_sequencer.shape[1])

prediction = model_nn.predict(sequences)
get_sentiment = sentiment[np.argmax(prediction[0])]


print("Text : ",text[0])
print("Sentiment: ",get_sentiment)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Text :  syukur
# Sentiment:  positive

# %% [markdown]
# Predict DataFrame

# %%
data_pre = df_predict['Tweet']

data_processed= []
for text in data_pre:
  text = data_prepocessing(text)
  data_processed.append(text)

feature = load_tokenizer.texts_to_sequences(data_processed)
sequences= pad_sequences(feature, maxlen=load_sequencer.shape[1])

prediction = model_nn.predict(sequences)
get_sentiment = np.argmax(prediction, axis=1)
get_sentiment = get_sentiment.reshape(-1,1)

get= []
for text in get_sentiment:
    sent= get_sent(text)
    get.append(sent)
# Out:
# 412/412 [==============================] - 1s 1ms/step

# %%
df_predict['Text_Clean']= data_processed
df_predict['Sentiment']= get

# %%
df_predict
# Out:
#                                                    Tweet  \
# 0      - disaat semua cowok berusaha melacak perhatia...
# 1      RT USER: USER siapa yang telat ngasih tau elu?...
# 2      41. Kadang aku berfikir, kenapa aku tetap perc...
# 3      USER USER AKU ITU AKU\n\nKU TAU MATAMU SIPIT T...
# 4      USER USER Kaum cebong kapir udah keliatan dong...
# ...                                                  ...
# 13164  USER jangan asal ngomong ndasmu. congor lu yg ...
# 13165                       USER Kasur mana enak kunyuk'
# 13166  USER Hati hati bisu :( .g\n\nlagi bosan huft \...
# 13167  USER USER USER USER Bom yang real mudah terdet...
# 13168  USER Mana situ ngasih(": itu cuma foto ya kuti...
#
#                                               Text_Clean Sentiment
# 0       cowok berusaha melacak perhatian gue lantas r...  negative
# 1       telat tau edan sarap gue bergaul cigax jifla ...  negative
# 2      kadang berpikir percaya tuhan jatuh berkali ka...  positive
# 3                                   ku tau matamu sipit   positive
# 4                kaum cebong kafir dongoknya dungu haha   negative
# ...                                                  ...       ...
# 13164              berbicara ndasmu congor sekateanjyng   negative
# 13165                                 kasur enak kunyuk   negative
# 13166                          hati hati bisu bosan duh   negative
# 13167  bom real mudah terdeteksi bom terkubur dahsyat...   neutral
# 13168                           situ foto ya kutil onta   negative
#
# [13169 rows x 3 columns]

# %%
import seaborn as sns
sns.countplot(x='Sentiment', data=df_predict)
# Out:
# <AxesSubplot: xlabel='Sentiment', ylabel='count'>

# %% [markdown]
# ## B. **Predict LSTM**

# %% [markdown]
# Predict Text

# %%
input_text = """
syukur
"""

text = [data_prepocessing(input_text)]
feature = load_tokenizer.texts_to_sequences(text)
sequences= pad_sequences(feature, maxlen=load_sequencer.shape[1])

prediction = model_lstm.predict(sequences)
get_sentiment = sentiment[np.argmax(prediction[0])]


print("Text : ",text[0])
print("Sentiment: ",get_sentiment)
# Out:
# 1/1 [==============================] - 0s 296ms/step
# Text :  syukur
# Sentiment:  neutral

# %% [markdown]
# Predict DataFrame

# %%
data_pre = df_predict['Tweet']

data_processed= []
for text in data_pre:
  text = data_prepocessing(text)
  data_processed.append(text)

feature = load_tokenizer.texts_to_sequences(data_processed)
sequences= pad_sequences(feature, maxlen=load_sequencer.shape[1])

prediction = model_lstm.predict(sequences)
get_sentiment = np.argmax(prediction, axis=1)
get_sentiment = get_sentiment.reshape(-1,1)

get= []
for text in get_sentiment:
    sent= get_sent(text)
    get.append(sent)
# Out:
# 412/412 [==============================] - 2s 6ms/step

# %%
df_predict['Text_Clean']= data_processed
df_predict['Sentiment']= get

# %%
df_predict
# Out:
#                                                    Tweet  \
# 0      - disaat semua cowok berusaha melacak perhatia...
# 1      RT USER: USER siapa yang telat ngasih tau elu?...
# 2      41. Kadang aku berfikir, kenapa aku tetap perc...
# 3      USER USER AKU ITU AKU\n\nKU TAU MATAMU SIPIT T...
# 4      USER USER Kaum cebong kapir udah keliatan dong...
# ...                                                  ...
# 13164  USER jangan asal ngomong ndasmu. congor lu yg ...
# 13165                       USER Kasur mana enak kunyuk'
# 13166  USER Hati hati bisu :( .g\n\nlagi bosan huft \...
# 13167  USER USER USER USER Bom yang real mudah terdet...
# 13168  USER Mana situ ngasih(": itu cuma foto ya kuti...
#
#                                               Text_Clean Sentiment
# 0       cowok berusaha melacak perhatian gue lantas r...  negative
# 1       telat tau edan sarap gue bergaul cigax jifla ...  negative
# 2      kadang berpikir percaya tuhan jatuh berkali ka...  positive
# 3                                   ku tau matamu sipit    neutral
# 4                kaum cebong kafir dongoknya dungu haha   negative
# ...                                                  ...       ...
# 13164              berbicara ndasmu congor sekateanjyng   negative
# 13165                                 kasur enak kunyuk   negative
# 13166                          hati hati bisu bosan duh   negative
# 13167  bom real mudah terdeteksi bom terkubur dahsyat...  negative
# 13168                           situ foto ya kutil onta   negative
#
# [13169 rows x 3 columns]

# %%
import seaborn as sns
sns.countplot(x='Sentiment', data=df_predict)
# Out:
# <AxesSubplot: xlabel='Sentiment', ylabel='count'>
